# %%
import cv


import pyautogui
import numpy as np
from matplotlib import pyplot as plt

# %%
scanner = cv.ScreenScanner()
boxes = scanner.get_screen_boxes()
print(boxes)
# Out:
# classes: 9
# [array([1.58841311e+03, 4.94136848e+01, 1.59626397e+03, 5.73354301e+01,
#        5.30988157e-01, 2.00000000e+00]), array([1.51585972e+03, 7.44174042e+01, 1.53764921e+03, 9.53862305e+01,
#        6.22106254e-01, 3.00000000e+00])]

# %%
textreader = cv.TextReader()
screen = cv.ScreenScanner.grab_screen()

textreader.get_text_boxes(screen, INVERT = False)        
textboxes = textreader.textboxes
print(textboxes)
textreader.draw_result()
# Out:
# [((47, 46, 56, 62), '>'), ((222, 77, 238, 93), '@'), ((424, 194, 444, 204), 'File'), ((415, 218, 428, 241), ' '), ((0, 429, 423, 584), '  '), ((0, 584, 423, 601), '  '), ((0, 601, 423, 635), '  '), ((0, 635, 423, 648), ' '), ((0, 648, 423, 669), ' '), ((0, 669, 423, 691), '  '), ((0, 691, 423, 716), ' '), ((0, 716, 423, 733), ' '), ((0, 733, 423, 750), ' '), ((0, 750, 423, 767), ' '), ((0, 767, 423, 784), ' '), ((0, 784, 423, 801), ' '), ((0, 801, 423, 818), ' '), ((0, 818, 423, 835), ' '), ((0, 835, 423, 852), ' '), ((0, 852, 423, 869), ' '), ((0, 869, 423, 887), ' '), ((0, 887, 423, 903), ' '), ((0, 903, 423, 920), ' '), ((0, 920, 423, 937), ' '), ((0, 937, 423, 954), ' '), ((0, 954, 423, 971), ' '), ((0, 971, 423, 988), ' '), ((0, 988, 1512, 1138), '  '), ((880, 988, 1512, 1005), ' '), ((0, 1138, 1646, 1162), '  '), ((475, 194, 496, 204), 'Edit'), ((457, 566, 470, 575), 'In'), ((481, 565, 507, 578), '[14]'), ((1011, 77, 1026, 93), 'iT}'), ((0, 0, 1920, 182), '   '), ((966, 149, 19
# ...
