# %%
import cv
import pyautogui
import numpy as np

# %%
# scanner = cv.ScreenScanner()
# boxes = scanner.get_screen_boxes()
# print(boxes)

# %%
textreader = cv.TextReader()
screen = pyautogui.screenshot()   
screen = np.array(screen)          

textreader.get_text_boxes(screen, INVERT = False)        
textboxes = textreader.textboxes
print(textboxes)
textreader.draw_result()
# Out:
# [((0, 0, 1920, 36), '  '), ((1015, 11, 1920, 36), '      '), ((0, 36, 1920, 69), ' '), ((0, 69, 943, 101), '  '), ((0, 101, 1464, 148), '     '), ((0, 148, 38, 181), '    '), ((0, 181, 38, 254), '    '), ((0, 254, 38, 296), '  '), ((0, 296, 38, 313), ' '), ((0, 313, 38, 330), ' '), ((0, 330, 38, 355), ' '), ((0, 355, 38, 448), '   '), ((0, 448, 38, 490), '   '), ((0, 501, 38, 541), '   '), ((0, 541, 38, 1138), '    '), ((0, 1138, 1646, 1162), '  '), ((76, 21, 84, 27), '¥'), ((959, 69, 1011, 101), '  '), ((1026, 69, 1920, 101), ' '), ((533, 110, 572, 124), 'main'), ((579, 114, 603, 124), 'Last'), ((607, 114, 674, 127), 'checkpoint:'), ((680, 114, 687, 124), 'B'), ((805, 117, 808, 124), '8'), ((814, 114, 845, 124), '12:07'), ((856, 114, 909, 127), '(unsaved'), ((913, 114, 966, 127), 'changes)'), ((1495, 114, 1531, 125), 'Logout'), ((424, 153, 444, 163), 'File'), ((475, 153, 496, 163), 'Edit'), ((527, 153, 554, 163), 'View'), ((1379, 150, 1418, 167), ' '), ((1464, 150, 1465, 168), '|'), ((1530, 153, 1541, 164), 'O'), ((415, 177, 428, 200), ' '), ((473, 261, 486, 270), 'In'), ((497, 260, 523, 273), '[1]:'), ((571, 260, 615, 273), 'import'), ((625, 263, 639, 270), 'cv'), ((571, 294, 615, 307), 'import'), ((625, 297, 662, 307), 'numpy'), ((671, 297, 685, 304), 'as'), ((694, 297, 708, 307), 'np'), ((473, 337, 486, 346), 'In'), ((497, 336, 523, 349), '[2]:'), ((570, 337, 578, 346), '#'), ((586, 339, 639, 346), 'Scanner'), ((648, 341, 655, 344), '='), ((663, 336, 800, 349), 'cv.ScreenScanner()'), ((570, 354, 578, 363), '#'), ((586, 353, 623, 363), 'boxes'), ((632, 360, 639, 361), '='), ((648, 353, 846, 366), 'scanner.get_screen_boxes()'), ((570, 371, 578, 380), '#'), ((473, 455, 486, 464), 'In'), ((497, 454, 523, 467), '[*]:'), ((570, 454, 647, 464), 'textreader'), ((656, 459, 661, 462), '='), ((671, 454, 784, 467), 'cv.TextReader()'), ((571, 474, 615, 481), 'screen'), ((625, 476, 631, 479), '='), ((641, 471, 807, 484), 'pyautogui.screenshot()'), ((571, 491, 615, 498), 'screen'), ((625, 493, 631, 496), '='), ((640, 488, 760, 501), 'np.array(screen)'), ((832, 523, 877, 532), 'INVERT'), ((887, 527, 892, 530), '='), ((902, 522, 945, 535), 'False)'), ((570, 539, 638, 549), 'textboxes'), ((648, 544, 654, 547), '='), ((571, 556, 606, 569), 'print'), ((612, 547, 692, 576), '(textboxes)'), ((0, 1138, 1920, 1200), '    '), ((1590, 1144, 1606, 1156), 'a'), ((1646, 1144, 1688, 1156), 'mo')]
